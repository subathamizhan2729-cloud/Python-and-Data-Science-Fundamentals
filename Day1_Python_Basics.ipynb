# %% [markdown]
# <a href="https://colab.research.google.com/github/subathamizhan2729-cloud/Python-and-Data-Science-Fundamentals/blob/main/Day1_Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PYTHON BASICS

# %%
name = input("What's your name? ")
age = int(input("What's your age? "))
print(f"Hi {name}, you are {age} years old!")

# Data types
x = 10        # int
y = 3.14      # float
z = "hello"   # str
is_true = True # bool
print(type(x), type(y), type(z), type(is_true))
# Out:
# What's your name? SUBAN
# What's your age? 19
# Hi SUBAN, you are 19 years old!
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>
